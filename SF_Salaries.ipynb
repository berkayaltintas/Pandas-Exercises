# %% [markdown]
# Dataseti bu linkten indirebilirsiniz.https://www.kaggle.com/datasets/kaggle/sf-salaries

# %% [markdown]
# # SF Salaries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Salaries.csv")
# Out:
# C:\Users\berkay\AppData\Local\Temp\ipykernel_7448\38999734.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("Salaries.csv")

# %%
data.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %% [markdown]
# # 1) Display Top 10 Rows of The Dataset #

# %%
data.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %%
data.head(-10) #--> Son 10 satırı getirmez.
# Out:
#             Id           EmployeeName  \
# 0            1         NATHANIEL FORD
# 1            2           GARY JIMENEZ
# 2            3         ALBERT PARDINI
# 3            4      CHRISTOPHER CHONG
# 4            5        PATRICK GARDNER
# ...        ...                    ...
# 148639  148640      Richard A Talbert
# 148640  148641     Charlene D Mccully
# 148641  148642  Raphael Marquis Goins
# 148642  148643      Dominic C Marquez
# 148643  148644             Kim Brewer
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...

# %% [markdown]
# # 2)Check Last 10 Rows of The Dataset #

# %%
data.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %%
data.tail(-10) #-->İlk 10 satırı getirmez.
# Out:
#             Id       EmployeeName  \
# 10          11      ARTHUR KENNEY
# 11          12   PATRICIA JACKSON
# 12          13  EDWARD HARRINGTON
# 13          14        JOHN MARTIN
# 14          15     DAVID FRANKLIN
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                                 JobTitle       BasePay  \
# 10      ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)     194999.39
# 11                       CAPTAIN III (POLICE DEPARTMENT)       99722.0
# 12                           EXECUTIVE CONTRACT EMPLOYEE     294580.02
# 13                                     DEPARTMENT HEAD V     271329.03
# 14                    BATTALION CHIEF, (FIRE DEPARTMENT)     174872.64
# ...                                                  ...           ...
# ...

# %% [markdown]
# # 3)  Find Shape of Our Dataset (Number of Rows And Number of Columns) #

# %%
data.shape
# Out:
# (148654, 13)

# %%
print("Number of Rows:",data.shape[0])
print("Number of Columns:",data.shape[1])
# Out:
# Number of Rows: 148654
# Number of Columns: 13

# %% [markdown]
# # 4)  Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement #

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# # 5) Check Null Values In The Dataset #

# %%
data.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# Bazı satırlar oldukça fazla sayıda eksik veriler bulunuyor.

# %% [markdown]
# # 6)  Drop ID, Notes, Agency, and Status Columns #

# %%
data.head(1)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN

# %%
data.drop(["Id","Notes","Agency","Status"],axis=1)
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %% [markdown]
# # 7) Get Overall Statistics About The Dataframe #

# %%
data.describe().T
# Out:
#                      count          mean           std      min        25%  \
# Id                148654.0  74327.500000  42912.857795     1.00  37164.250
# TotalPay          148654.0  74768.321972  50517.005274  -618.13  36168.995
# TotalPayBenefits  148654.0  93692.554811  62793.533483  -618.13  44065.650
# Year              148654.0   2012.522643      1.117538  2011.00   2012.000
# Notes                  0.0           NaN           NaN      NaN        NaN
#
#                        50%         75%        max
# Id                74327.50  111490.750  148654.00
# TotalPay          71426.61  105839.135  567595.43
# TotalPayBenefits  92404.09  132876.450  567595.43
# Year               2013.00    2014.000    2014.00
# Notes                  NaN         NaN        NaN

# %%
data.describe(include="all")
# Out:
#                    Id EmployeeName          JobTitle   BasePay  OvertimePay  \
# count   148654.000000       148654            148654  148049.0     148654.0
# unique            NaN       110811              2159  109900.0      66555.0
# top               NaN    Kevin Lee  Transit Operator       0.0          0.0
# freq              NaN           13              7036     875.0      66103.0
# mean     74327.500000          NaN               NaN       NaN          NaN
# std      42912.857795          NaN               NaN       NaN          NaN
# min          1.000000          NaN               NaN       NaN          NaN
# 25%      37164.250000          NaN               NaN       NaN          NaN
# 50%      74327.500000          NaN               NaN       NaN          NaN
# 75%     111490.750000          NaN               NaN       NaN          NaN
# max     148654.000000          NaN               NaN       NaN          NaN
#
# ...

# %% [markdown]
# # 8) Find Occurrence of The Employee Names  (Top 5) #

# %%
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
data["EmployeeName"].value_counts().head(5)
# Out:
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: EmployeeName, dtype: int64

# %% [markdown]
# # 9)  Find The Number of Unique Job Titles #

# %%
data["JobTitle"].nunique() #-->Kaç farklı nunique değeri varsa sayar getirir.
# Out:
# 2159

# %% [markdown]
# # 10) Total Number of Job Titles Contain Captain #

# %%
len(data[data["JobTitle"].str.contains("Captain",case=False)])
# Out:
# 552

# %% [markdown]
# # 11) Display All the Employee Names From Fire Department #

# %%
data["JobTitle"]
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
data[data["JobTitle"].str.contains("fire",case=False)]["EmployeeName"].reset_index()
# Out:
#        index        EmployeeName
# 0          4     PATRICK GARDNER
# 1          6           ALSON LEE
# 2          8      MICHAEL MORRIS
# 3          9  JOANNE HAYES-WHITE
# 4         10       ARTHUR KENNEY
# ...      ...                 ...
# 5874  145956    Kenneth C Farris
# 5875  147556       Edward A Dunn
# 5876  148021      Kari A Johnson
# 5877  148209        Sheryl K Lee
# 5878  148554     Lawrence F Gatt
#
# [5879 rows x 2 columns]

# %% [markdown]
# # 12) Replace 'Not Provided' in EmployeeName' Column to NaN  #

# %%
import numpy as np

# %%
data["EmployeeName"]=data["EmployeeName"].replace("Not provided",np.nan)

# %%
data["EmployeeName"]
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %% [markdown]
# NaN yapmak için Numpy kütüphanemizi import etmemiz gerekmektedir.

# %%
data.drop(data.isnull().sum(axis=1)==3.index,axis=0)
# Out:
#   Input In [71]
#     data.drop(data.isnull().sum(axis=1)==3.index,axis=0)
#                                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 13)  Find Job Title of ALBERT PARDINI #

# %%
data[data["EmployeeName"]=="ALBERT PARDINI"]["JobTitle"].reset_index()
# Out:
#    index                         JobTitle
# 0      2  CAPTAIN III (POLICE DEPARTMENT)

# %% [markdown]
# # 14) How Much ALBERT PARDINI Make (Include Benefits)? #

# %%
data[data["EmployeeName"]=="ALBERT PARDINI"]["TotalPayBenefits"]
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64
